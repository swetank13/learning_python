# %% [markdown]
# <h2 align="center">Matplotlib, Seaborn Tutorial</h2>

# %% [markdown]
# - Install matplotlib and seaborn by running following commands in your command prompt
#   - pip install matplotlib
#   - pip install seaborn

# %% [markdown]
# ### Important Notes
# - The purpose and best use cases for each plot:
#   - Line charts for trends over time or continuous data.
#   - Pie charts for showing proportions of categories.
#   - Bar charts for comparing categorical data or aggregated summaries.
#   - Histograms for understanding the distribution of numeric data.
#   - Scatter plots for investigating relationships or correlations between variables.
# - `Matplotlib` is a low-level library providing extensive control and flexibility for all types of plots, while `Seaborn` is built on top of Matplotlib and offers higher-level, more visually appealing statistical graphics with simpler syntax for complex visualizations.

# %%
import pandas as pd

df_sales = pd.read_excel("../data/raw/linechart.xlsx")
df_sales.head()
# Out:
#    Quarter  Fridge  Dishwasher  Washing Machine
# 0  Q1 2022    12.5         8.0              9.2
# 1  Q2 2022    11.0         7.5              8.5
# 2  Q3 2022    13.2         9.0              7.5
# 3  Q4 2022    16.4        11.0              7.6
# 4  Q1 2023    13.8         9.5              6.8

# %% [markdown]
# ### Line Chart
# - Shows trends over continuous data or time.

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(12,2))
plt.plot(df_sales["Quarter"], df_sales["Fridge"], color="blue", label="Fridge")
plt.plot(df_sales["Quarter"], df_sales["Dishwasher"], color="orange", label="Dishwasher")
plt.plot(df_sales["Quarter"], df_sales["Washing Machine"], color="green", label="Washing Machine")

plt.title("Product Sales")
plt.xlabel("Quarter")
plt.ylabel("Million $")

plt.legend()

plt.show()

# %% [markdown]
# ### Pie Chart
# - Shows proportions of categories

# %%
total_sales = df_sales[["Fridge","Dishwasher","Washing Machine"]].sum()
total_sales
# Out:
# Fridge             80.9
# Dishwasher         53.0
# Washing Machine    45.6
# dtype: float64

# %%
plt.pie(total_sales, labels=total_sales.index, autopct='%1.1f%%', startangle=140, explode=(0.1,0,0), shadow=True)
plt.show()

# %% [markdown]
# ### Bar Chart
# - Useful for comparing categories aggregated summary values.

# %%
df_sales.plot(kind="bar", x="Quarter")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# To use Quarters as X axis, we can set them as an index on a dataframe and then use plot function

# %%
df_sales_2 = df_sales.set_index("Quarter")
df_sales_2
# Out:
#          Fridge  Dishwasher  Washing Machine
# Quarter
# Q1 2022    12.5         8.0              9.2
# Q2 2022    11.0         7.5              8.5
# Q3 2022    13.2         9.0              7.5
# Q4 2022    16.4        11.0              7.6
# Q1 2023    13.8         9.5              6.8
# Q2 2023    14.0         8.0              6.0

# %%
df_sales_2.plot(kind="bar")
plt.xticks(rotation=45)
plt.show()

# %%
df_sales_2.plot(kind="barh")
plt.show()

# %% [markdown]
# ### Histogram
# - Shows data distribution by binning values.

# %%
df_score = pd.read_excel("../data/raw/histograms.xlsx")
df_score.head(3)
# Out:
#       Name  Exam_Score
# 0    Aarav          45
# 1  Michael          71
# 2    Bilal          59

# %%
plt.hist(df_score["Exam_Score"], density=True)
plt.show()

# %%
import seaborn as sns

sns.histplot(df_score["Exam_Score"], kde=True)

plt.xlabel("Score")
plt.ylabel("Count")
plt.title("Exam Scores")
plt.show()

# %% [markdown]
# ### Scatter Plot
# - Shows relationships or correlations between two variables.

# %%
df = pd.read_excel("../data/raw/scatter_plot.xlsx")
df
# Out:
#    area_square_ft  price
# 0             650     55
# 1             800     91
# 2             950     96
# 3            1100    122
# 4             500     34
# 5            1200    120
# 6             700     95
# 7             850    110
# 8            1000    115
# 9            1150     41

# %%
sns.scatterplot(data=df, x="area_square_ft", y="price")

plt.show()
